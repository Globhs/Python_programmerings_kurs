# %% [markdown]
# # Uppgift 1

# %% [markdown]
# En funktion är en block kod som kan förväntas att användas igen.

# %% [markdown]
# # Uppgift 2

# %% [markdown]
# Parametrar kan ta emot argument till funktioner, dem fungerar som inputslotts åt funktioner.
# Parametrar kan se lite olika ut och ha olika funktionalitet. positional, keyword, osv

# %% [markdown]
# # Uppgift 3

# %%
def uppercase_converter(x):
    upper_string = x.upper()
    return(upper_string)

uppercase_converter("hello")

# %% [markdown]
# # Uppgift 4

# %%
def add_subtract_function(a, b):
    result_1 = a + b
    result_2 = a - b
    return(result_1, result_2)

add_subtract_function(7, 3)

# %% [markdown]
# # Uppgift 5

# %%
def function(a, /, b, *, c):
    result = a + b * c
    return result

function(2, 5, c=10)

# %% [markdown]
# # Uppgift 6

# %% [markdown]
# koden definerar en function "my_sum_function()" och sedan tildelar den funktionen till variablen a.

# %% [markdown]
# # Uppgift 7

# %%
def add_or_multiply(a, b, *, method):
    if method == "add":
        result = a + b
        return result
    elif method == "multiply":
        result = a * b
        return result
    else:
        print('Choose either "add" or "multiply')

# add_or_multiply(2, 5, method="add")
# add_or_multiply(2, 5, method="multiply")
# add_or_multiply(2, 5, method="Wrong")

# %%
name = input("What is your name dear stranger?")

print("Mom, I met a person who's name is:", name)
# Out:
# What is your name dear stranger? Kasper
# Mom, I met a person who's name is: Kasper

# %% [markdown]
# Koden tar in en input från usern och lagrar den i variablen name, sedan printar den ut en sträng i kombination med variablen.

# %%
# Uppgift 1
num_1 = 5
num_2 = 3
my_result = num_1 + num_2
print(my_result)
# Out:
# 8

# %%
# Uppgift 2
number_1 = 10
number_2 = 7
my_mult_result = number_1 * number_2
print(my_mult_result)
# Out:
# 70

# %%
# Uppgift 3
# Här används modulos för att få resten av 10 som delas med 3, vilket ger resultatet 1.
result = 10 % 3
print(result)
# Out:
# 1

# %%
# Uppgift 4
# Här används heltalsdivision alltså // som delar ett tal och avrundar nedåt till det närmsta heltalet.
result = 27 // 6
print(result)
# Out:
# 4

# %%
# Uppgift 5
# Man måste använda dubbel-citattecken för att denna sträng ska fungera, då strängen redan har singel-citattecken i sig.
print("it's fun to learn Python!")
# Out:
# it's fun to learn Python!

# %%
# Uppgift 6
# Strängen "ha" upprepas tre gånger och printas ut som "hahaha".
print("ha" * 3)
# Out:
# hahaha

# %%
# Uppgift 7
namn_str = "Mitt namn är Anna."
namn = namn_str[13:17]
print(namn)
# Out:
# Anna

# %%
# Uppgift 8
full_name = "Anna Andersson"
print(len(full_name))
# Out:
# 14

# %%
# Uppgift 9 a)
founder = "Guido"
language = "Python"
print(f"Hello {founder}, {language} is really fun to learn!")
# Out:
# Hello Guido, Python is really fun to learn!

# %%
# Uppgift 9 b)
founder = "Guido van Rossum"
print(f"Hello {founder}, {language} is really fun to learn!")
# Out:
# Hello Guido van Rossum, Python is really fun to learn!

# %%
# Uppgift 10
# En tuple är immutable vilket betyder att man inte kan ändra något i den.
#my_first_tuple = (10, 5, 'hi', 3)
#my_first_tuple[1] = 10

# %%
# Uppgift 11
# Koden kommer först printa ut index 0 vilket är languages,
# sen den sista indexet vilket är apples,
# de andre indexet i listan vilket är "C"
my_tuple = ('languages', ['Python', 'Java', 'C', 'R'],'apples')
64
print(my_tuple[0])
print(my_tuple[-1])
print(my_tuple[1][2])
# Out:
# languages
# apples
# C

# %%
# Uppgift 12
type(my_tuple)
# Out:
# tuple

# %%
# Uppgift 13 
# Koden ändrar värdet i index 1 från 5 till 7
my_first_list = [10, 5, 'hi', 3]
my_first_list[1] = 7
print(my_first_list)
# Out:
# [10, 7, 'hi', 3]

# %%
# Uppgift 14
type(my_first_list)
# Out:
# list

# %%
# Uppgift 15
shopping_list = ['apple', 'banana', 'grapes', 'eggs', 'milk']
print(len(shopping_list))
# Out:
# 5

# %%
# Uppgift 16
shopping_list.append('bread')
print(shopping_list)
# Out:
# ['apple', 'banana', 'grapes', 'eggs', 'milk', 'bread']

# %%
# Uppgift 17
my_numbers = [1, 7, 2, 7, 10, 7]
print(my_numbers.count(7))
# Out:
# 3

# %%
# Uppgift 18
one_tuple = (10, 5, 3)
one_list = list(one_tuple)
print(one_list)
# Out:
# [10, 5, 3]

# %%
# Uppgift 19 – Slå upp värde i dictionary
# Koden nedanstående har skapat en dictionary med namn och deras värde.
# Sedan printar vi ut Goran's värde.
my_first_dict = {'Anna': 38, 'Goran': 19, 'Lennart': 59, 'Halimah': 28}
print(my_first_dict['Goran'])
# Out:
# 19

# %%
# Uppgift 20
type(my_first_dict)
# Out:
# dict

# %%
# Uppgift 21
# elementet 5 printas bara ut en gång då detta är en tuple, det innebär att den bara kan hålla unika värden.
my_set = {10, 5, 2, 5, 5}
print(my_set)
# Out:
# {10, 2, 5}

# %%
# Uppgift 22a
A = {1, 2, 3, 4, 5}
B = {3, 10, 5, 7}
print(A.intersection(B))
# Out:
# {3, 5}

# %%
# Uppgift 22b
A = {1, 2, 3, 4, 5}
B = {3, 10, 5, 7}
print(A.union(B))
# Out:
# {1, 2, 3, 4, 5, 7, 10}

# %%
# Uppgift 22c
A = {1, 2, 3, 4, 5}
B = {3, 10, 5, 7}
print(A.difference(B))
# Out:
# {1, 2, 4}

# %%
# Uppgift 23a
list_a = [1, 2, 3, 4, 5]
list_b = [5, 6, 10, 21]
common_elements = set(list_a).intersection(set(list_b))
print(common_elements)
# Out:
# {5}

# %%
# Uppgift 23b
list_a = [1, 2, 3, 4, 5]
list_b = [5, 6, 10, 21]
all_elements = set(list_a).union(set(list_b))
print(all_elements)
# Out:
# {1, 2, 3, 4, 5, 6, 10, 21}

# %%
# Uppgift 24
duplicate_values = (10, 2, 2, 10, 1)
set_values = set(duplicate_values)
print(set_values)
# Out:
# {1, 10, 2}
